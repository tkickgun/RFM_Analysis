# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
sales_data = pd.read_csv('sales_data.csv',parse_dates=['OrderDate'],dtype={'_CustomerID':'str'})

# %%
sales_data.dtypes
# Out:
# OrderNumber                 object
# Sales Channel               object
# WarehouseCode               object
# ProcuredDate                object
# OrderDate           datetime64[ns]
# ShipDate                    object
# DeliveryDate                object
# CurrencyCode                object
# _SalesTeamID                 int64
# _CustomerID                 object
# _StoreID                     int64
# _ProductID                   int64
# Order Quantity               int64
# Discount Applied           float64
# Unit Price                 float64
# Unit Cost                  float64
# dtype: object

# %%
df = sales_data.copy()

# %%
df.head()
# Out:
#    OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate   ShipDate  \
# 0  SO - 000101      In-Store  WARE-UHY1004   12/31/2017 2018-05-31  6/14/2018
# 1  SO - 000102        Online  WARE-NMK1003   12/31/2017 2018-05-31  6/22/2018
# 2  SO - 000103   Distributor  WARE-UHY1004   12/31/2017 2018-05-31  6/21/2018
# 3  SO - 000104     Wholesale  WARE-NMK1003   12/31/2017 2018-05-31   6/2/2018
# 4  SO - 000105   Distributor  WARE-NMK1003    4/10/2018 2018-05-31  6/16/2018
#
#   DeliveryDate CurrencyCode  _SalesTeamID _CustomerID  _StoreID  _ProductID  \
# 0    6/19/2018          USD             6          15       259          12
# 1     7/2/2018          USD            14          20       196          27
# 2     7/1/2018          USD            21          16       213          16
# 3     6/7/2018          USD            28          48       107          23
# 4    6/26/2018          USD            22          49       111          26
#
#    Order Quantity  Discount Applied  Unit Price  Unit Cost
# 0               5             0.075      1963.1   1001.181
# 1               3             0.075      3939.6   3348.660
# 2               1             0.050      1775.5    781.220
# 3               8             0.075      2324.9   1464.687
# 4               8             0.100      1822.4   1476.144

# %%
df['Revenue'] = ((df['Unit Price'] - (df['Unit Price']*df['Discount Applied'])) - df['Unit Cost']) * df['Order Quantity']

# %%
columns = ['OrderNumber','_CustomerID','OrderDate','Revenue']
rfm_data = df[columns]

# %%
rfm_data
# Out:
#        OrderNumber _CustomerID  OrderDate    Revenue
# 0      SO - 000101          15 2018-05-31  4073.4325
# 1      SO - 000102          20 2018-05-31   886.4100
# 2      SO - 000103          16 2018-05-31   905.5050
# 3      SO - 000104          48 2018-05-31  5486.7640
# 4      SO - 000105          49 2018-05-31  1312.1280
# ...            ...         ...        ...        ...
# 7986  SO - 0008087          41 2020-12-30    94.9725
# 7987  SO - 0008088          29 2020-12-30  6725.4600
# 7988  SO - 0008089          32 2020-12-30  1338.9950
# 7989  SO - 0008090          42 2020-12-30  1286.4000
# 7990  SO - 0008091          41 2020-12-30  3371.7750
#
# [7991 rows x 4 columns]

# %%
max_order_date = max(df['OrderDate'])

today = max_order_date + timedelta(days=2)

# %%
rfm = rfm_data.groupby('_CustomerID').agg({'OrderDate': lambda x: (today-x.max()).days,
                                     'OrderNumber':'count','Revenue':'sum'})

# %%
rfm.columns = ['Recency', 'Frequency', 'Monetary']

# %%
r = pd.qcut(rfm['Recency'],q=5,labels = range(5,0,-1))
f = pd.qcut(rfm['Frequency'],q=5,labels = range(1,6))
m = pd.qcut(rfm['Monetary'],q=5,labels = range(1,6))

# %%
rfm_df = rfm.assign(R=r.values,F=f.values,M=m.values)
rfm_df
# Out:
#              Recency  Frequency     Monetary  R  F  M
# _CustomerID
# 1                  9        152  335933.6115  2  2  1
# 10                15        158  435122.1870  1  3  3
# 11                 6        178  487614.2415  3  5  5
# 12                 3        210  616719.2550  5  5  5
# 13                 4        171  441003.2795  4  4  3
# 14                 5        157  381450.0280  3  3  2
# 15                 4        142  441668.3550  4  1  4
# 16                 3        135  402938.7705  5  1  2
# 17                 6        175  534027.3860  3  5  5
# 18                 6        186  451637.7540  3  5  4
# 19                 3        165  443231.8335  5  4  4
# 2                  9        135  327409.1345  2  1  1
# 20                 9        167  439147.9490  2  4  3
# 21                 3        164  479383.0905  5  4  5
# 22                 4        140  401721.7825  4  1  2
# 23                12        164  449782.2895  1  4  4
# 24                23        151  352505.5255  1  2  1
# 25                 5        162  461601.9940  3  4  4
# 26                11        153  375766.6860  1  2  2
# 27                 3        144  336959.7835  5  1  1
# 28                 8        145  348495.4750  2  1  1
# 29                 2        179  531770.6920  5  5  5
# 3                 10        181  466220.1365  2  5  4
# 30                 4        159  442372.3910  4  3  4
# 31                 4        152  398616.8350  4  2  2
# 32                 2        173  435206.0710  5  5  3
# 33                 4        156  495444.2635  4  2  5
# 34                15        176  496418.6780  1  5  5
# 35                10        145  345844.5865  2  1  1
# 36                 4        156  441225.9540  4  2  3
# 37                11        152  425241.0940  1  2  3
# 38                 8        150  350687.6480  2  1  1
# 39                 4        176  471608.1425  4  5  4
# 4                  5        167  526981.0630  3  4  5
# 40                 9        150  406016.9180  2  1  2
# 41                 2        161  403693.2910  5  3  2
# 42                 2        161  427159.6055  5  3  3
# 43                 5        151  372471.3245  3  2  2
# 44                 3        156  348209.0500  5  2  1
# 45                 5        156  407145.0305  3  2  3
# 46                 4        157  378414.7270  4  3  2
# 47                 8        168  442845.8465  2  4  4
# 48                10        172  424970.7490  2  5  3
# 49                 7        152  354161.3300  2  2  1
# 5                 30        159  445632.7450  1  3  4
# 50                16        163  498384.9940  1  4  5
# 6                  4        143  392141.0840  4  1  2
# 7                  3        153  414155.9775  5  2  3
# 8                  5        142  338000.0590  3  1  1
# 9                  8        171  500166.4570  2  4  5

# %%
rfm_df['rfm_group'] = rfm_df[['R','F','M']].apply(lambda x: '-'.join(x.astype(str)),axis=1)
rfm_df['rfm_score'] = rfm_df[['R','F','M']].sum(axis=1)

# %%
rfm_df.sort_values('rfm_score',ascending=False).reset_index()
# Out:
#    _CustomerID  Recency  Frequency     Monetary  R  F  M rfm_group  rfm_score
# 0           12        3        210  616719.2550  5  5  5     5-5-5         15
# 1           29        2        179  531770.6920  5  5  5     5-5-5         15
# 2           21        3        164  479383.0905  5  4  5     5-4-5         14
# 3           19        3        165  443231.8335  5  4  4     5-4-4         13
# 4           17        6        175  534027.3860  3  5  5     3-5-5         13
# 5           11        6        178  487614.2415  3  5  5     3-5-5         13
# 6           32        2        173  435206.0710  5  5  3     5-5-3         13
# 7           39        4        176  471608.1425  4  5  4     4-5-4         13
# 8            4        5        167  526981.0630  3  4  5     3-4-5         12
# 9           18        6        186  451637.7540  3  5  4     3-5-4         12
# 10          30        4        159  442372.3910  4  3  4     4-3-4         11
# 11           3       10        181  466220.1365  2  5  4     2-5-4         11
# 12          33        4        156  495444.2635  4  2  5     4-2-5         11
# 13          34       15        176  496418.6780  1  5  5     1-5-5         11
# 14          13        4        171  441003.2795  4  4  3     4-4-3         11
# 15          25        5        162  461601.9940  3  4  4     3-4-4         11
# 16          42        2        161  427159.6055  5  3  3     5-3-3         11
# 17           9        8        171  500166.4570  2  4  5     2-4-5         11
# 18           7        3        153  414155.9775  5  2  3     5-2-3         10
# 19          47        8        168  442845.8465  2  4  4     2-4-4         10
# 20          41        2        161  403693.2910  5  3  2     5-3-2         10
# 21          48       10        172  424970.7490  2  5  3     2-5-3         10
# 22          50       16        163  498384.9940  1  4  5     1-4-5         10
# 23          23       12        164  449782.2895  1  4  4     1-4-4          9
# 24          46        4        157  378414.7270  4  3  2     4-3-2          9
# 25          15        4        142  441668.3550  4  1  4     4-1-4          9
# 26          20        9        167  439147.9490  2  4  3     2-4-3          9
# 27          36        4        156  441225.9540  4  2  3     4-2-3          9
# 28          44        3        156  348209.0500  5  2  1     5-2-1          8
# 29           5       30        159  445632.7450  1  3  4     1-3-4          8
# 30          31        4        152  398616.8350  4  2  2     4-2-2          8
# 31          16        3        135  402938.7705  5  1  2     5-1-2          8
# 32          14        5        157  381450.0280  3  3  2     3-3-2          8
# 33          45        5        156  407145.0305  3  2  3     3-2-3          8
# 34          10       15        158  435122.1870  1  3  3     1-3-3          7
# 35          27        3        144  336959.7835  5  1  1     5-1-1          7
# 36           6        4        143  392141.0840  4  1  2     4-1-2          7
# 37          22        4        140  401721.7825  4  1  2     4-1-2          7
# 38          43        5        151  372471.3245  3  2  2     3-2-2          7
# 39          37       11        152  425241.0940  1  2  3     1-2-3          6
# 40           1        9        152  335933.6115  2  2  1     2-2-1          5
# 41          40        9        150  406016.9180  2  1  2     2-1-2          5
# 42           8        5        142  338000.0590  3  1  1     3-1-1          5
# 43          26       11        153  375766.6860  1  2  2     1-2-2          5
# 44          49        7        152  354161.3300  2  2  1     2-2-1          5
# 45           2        9        135  327409.1345  2  1  1     2-1-1          4
# 46          24       23        151  352505.5255  1  2  1     1-2-1          4
# 47          38        8        150  350687.6480  2  1  1     2-1-1          4
# 48          28        8        145  348495.4750  2  1  1     2-1-1          4
# 49          35       10        145  345844.5865  2  1  1     2-1-1          4
